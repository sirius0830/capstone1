# %% [markdown]
# <a href="https://colab.research.google.com/github/sirius0830/capstone1/blob/master/telegrambot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   /tag {태그} -> 태그에 문자열 검색, 사진 출력
# *   /reset -> 태그 초기화 확인

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
pip install python-telegram-bot

# %%
pip install lxml

# %%
#이 부분은 처음 한번만 실행.
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
#크롤링으로 광주 날씨 받아오기
from selenium import webdriver
from selenium.webdriver.common.by import By
from urllib.request import urlretrieve
import os
import time
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
import pandas as pd
from selenium.webdriver.common import keys

# HTTP 통신
import requests
from urllib.parse import urlencode, quote_plus, urlparse
from urllib.request import urlopen
import urllib

# 데이터 가공
import json

options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

todayTemp = ""

#csv
csv_test = pd.read_csv('/content/drive/MyDrive/스냅.csv', encoding = 'utf-8')
csv_test.columns = ['idx','날짜','평균','최저','최고','풍속','태그','사진 링크']

#사진 링크 리스트
link = csv_test['사진 링크']
linkVal = link.values
linkList = linkVal.tolist()

#기온 리스트
temp = csv_test['평균']
tempList = temp.values.tolist()

#태그 리스트
tagList = csv_test['태그'].values.tolist()


#조건 만족하는 링크, 기온, 태그 리스트
datalinkList = []
datatempList = []
datatagList = []



def getTemp():
  url = "https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=광주+날씨"
  
  r = requests.get(url)
  bs = BeautifulSoup(r.text,"lxml")
  
  temperature = bs.select("div.temperature_text")
  temperature = temperature[0].text.strip()

  #소수점 버리고 int로 변경
  todayTemp = int(temperature[5:6])

  return todayTemp

todayTemp = getTemp()
#print(todayTemp)

#todayTemp랑 비슷한 기온인 날 링크들 리스트 만들기
#스냅 사진 1440장
#온도 +- 2도

for i in range(1440):
  if tempList[i] >= todayTemp - 2 and tempList[i] <= todayTemp + 2:
    datalinkList.append(linkList[i])
    datatagList.append(tagList[i])
    datatempList.append(tempList[i])

#태그
#반팔
shorttoplinkList = []
shorttoptempList = []
shorttoptagList = []
for i in range(len(datalinkList)):
  if '반팔' in str(datatagList[i]):
    shorttoplinkList.append(datalinkList[i])
    shorttoptempList.append(datatempList[i])
    shorttoptagList.append(datatagList[i])

#긴팔
longtoplinkList = []
longtoptempList = []
longtoptagList = []
for i in range(len(datalinkList)):
  if '긴팔' in str(datatagList[i]):
    longtoplinkList.append(datalinkList[i])
    longtoptempList.append(datatempList[i])
    longtoptagList.append(datatagList[i])

#후드티
hoodlinkList = []
hoodtempList = []
hoodtagList = []
for i in range(len(datalinkList)):
  if '후드티' in str(datatagList[i]):
    hoodlinkList.append(datalinkList[i])
    hoodtempList.append(datatempList[i])
    hoodtagList.append(datatagList[i])

#셔츠
shirtlinkList = []
shirttempList = []
shirttagList = []
for i in range(len(datalinkList)):
  if '셔츠' in str(datatagList[i]):
    shirtlinkList.append(datalinkList[i])
    shirttempList.append(datatempList[i])
    shirttagList.append(datatagList[i])

#민소매
slesslinkList = []
slesstempList = []
slesstagList = []
for i in range(len(datalinkList)):
  if '민소매' in str(datatagList[i]):
    slesslinkList.append(datalinkList[i])
    slesstempList.append(datatempList[i])
    slesstagList.append(datatagList[i])

#코트
coatlinkList = []
coattempList = []
coattagList = []
for i in range(len(datalinkList)):
  if '코트' in str(datatagList[i]):
    coatlinkList.append(datalinkList[i])
    coattempList.append(datatempList[i])
    coattagList.append(datatagList[i])

#기타 재킷
jacketlinkList = []
jackettempList = []
jackettagList = []
for i in range(len(datalinkList)):
  if '기타 재킷' in str(datatagList[i]):
    jacketlinkList.append(datalinkList[i])
    jackettempList.append(datatempList[i])
    jackettagList.append(datatagList[i])

#긴바지
lbotlinkList = []
lbottempList = []
lbottagList = []
for i in range(len(datalinkList)):
  if '긴바지' in str(datatagList[i]):
    lbotlinkList.append(datalinkList[i])
    lbottempList.append(datatempList[i])
    lbottagList.append(datatagList[i])

#숏팬츠
sbotlinkList = []
sbottempList = []
sbottagList = []
for i in range(len(datalinkList)):
  if '숏팬츠' in str(datatagList[i]):
    sbotlinkList.append(datalinkList[i])
    sbottempList.append(datatempList[i])
    sbottagList.append(datatagList[i])


#패딩
padlinkList = []
padtempList = []
padtagList = []
for i in range(len(datalinkList)):
  if '패딩' in str(datatagList[i]):
    padlinkList.append(datalinkList[i])
    padtempList.append(datatempList[i])
    padtagList.append(datatagList[i])

#치마
skirtlinkList = []
skirttempList = []
skirttagList = []
for i in range(len(datalinkList)):
  if '치마' in str(datatagList[i]):
    skirtlinkList.append(datalinkList[i])
    skirttempList.append(datatempList[i])
    skirttagList.append(datatagList[i])

#원피스
oplinkList = []
optempList = []
optagList = []
for i in range(len(datalinkList)):
  if '원피스' in str(datatagList[i]):
    oplinkList.append(datalinkList[i])
    optempList.append(datatempList[i])
    optagList.append(datatagList[i])

# %%
import datetime
from time import sleep
import telegram
from telegram import InlineKeyboardButton,InlineKeyboardMarkup, ChatAction
from telegram.ext import Updater
from telegram.ext import MessageHandler, Filters
from telegram.ext import CommandHandler, CallbackQueryHandler
import time
from telegram.inline.inlinekeyboardbutton import InlineKeyboardButton
import re

# Pandas
import pandas as pd

import random
 
token = "5837010733:AAGLuzEgbvf_zp9hmB3_WZj7eLTsVZaTdeM"
id = "5095408838"

#초기 태그
tag = ""

bot = telegram.Bot(token)
bot.sendMessage(chat_id=id, text="테스트 중입니다.")

updater = Updater(token = token, use_context = True)
dispatcher = updater.dispatcher

bot.sendMessage(chat_id=id, text="업그레이드.")

# command hander
def start(update, context):
    context.bot.send_message(chat_id=update.effective_chat.id, text="ㅇㅇ")

#도움말
def help(update, context) :
    text = "날씨 명령어 : /weather {날씨}\n태그 명령어 : /tag {태그}\n초기화 명령어 : /reset\n태그 종류 : /taghelp"
    context.bot.send_message(chat_id=update.effective_chat.id, text=text)


def taghelp(update, context) :
  text = "/tag : {태그}\n반팔\n긴팔\n후드티\n셔츠\n민소매\n패딩\n코트\n기타 재킷\n긴바지\n숏팬츠\n치마\n원피스"
  context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=text)

def tag(update, context):
  tag = context.args[0]
  if tag == '반팔':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='반팔'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)
    
  elif tag == '긴팔':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='긴팔'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)
  
  elif tag == '후드티':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='후드티'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)

  elif tag == '셔츠':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='셔츠'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)
  
  elif tag == '민소매':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='민소매'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)

  elif tag == '패딩':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='패딩'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= 'tag : {}'.format(tag), reply_markup=reply_markup)

  elif tag == '코트':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='코트'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= 'tag : {}'.format(tag), reply_markup=reply_markup)

  elif tag == '기타 재킷':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='기타 재킷'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)

  elif tag == '긴바지':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='긴바지'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)

  elif tag == '치마':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='치마'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)

  elif tag == '숏팬츠':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='숏팬츠'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)

  elif tag == '원피스':
    btn1 = [[InlineKeyboardButton(text=tag, callback_data='원피스'),
             InlineKeyboardButton( '태그 초기화', callback_data='reset')]]
    reply_markup = InlineKeyboardMarkup( btn1 )
    context.bot.send_message(chat_id=update.message.chat_id, text= "tag : {}".format(tag), reply_markup=reply_markup)

def cmd_task_buttons(update, context):
    task_buttons = [[InlineKeyboardButton(text='사진 보기', callback_data="snap")]]
    reply_markup = InlineKeyboardMarkup( task_buttons )

    context.bot.send_message(
        chat_id=update.message.chat_id
        , text='작업을 선택해주세요.'
        , reply_markup=reply_markup
    )

def cb_button(update, context):
# 받은 메시지 data에서 버튼에 설정한 query_data를 받을 수 있습니다.
  query = update.callback_query
  data = query.data
  if data == "snap": 
    #날씨 맞게 랜덤 전송
    i = random.randint(0,len(datalinkList))

    #스냅 사진 기온, 태그 데이터 
    msg = str(datatempList[i]) + "℃\n" + str(datatagList[i])
    context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=datalinkList[i])
    
    context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
    
  elif data == 'tag':
    context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="태그 명령어 : /tag {태그}")

#태그
  elif data == '반팔':
      if (len(shorttoplinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")

      i = random.randint(0,len(shorttoplinkList))

      msg = str(shorttoptempList[i]) + "℃\n" + str(shorttoptagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=shorttoplinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
    
  elif data == '긴팔':
      if (len(longtoplinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(longtoplinkList))

      msg = str(longtoptempList[i]) + "℃\n" + str(longtoptagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=longtoplinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
      
  elif data == '후드티':
      if (len(hoodlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(hoodlinkList))

      msg = str(padtempList[i]) + "℃\n" + str(padtagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=hoodlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
      
  elif data == '민소매':
      if (len(slesslinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(slesslinkList))

      msg = str(slesstempList[i]) + "℃\n" + str(slesstagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=slesslinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
      
  elif data == '셔츠':
      if (len(shirtlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(shirtlinkList))

      msg = str(shirttempList[i]) + "℃\n" + str(shirttagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=shirtlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)

  elif data == '패딩':
      if (len(padlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(padlinkList))

      msg = str(padtempList[i]) + "℃\n" + str(padtagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=padlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
    
  elif data == '치마':
      if (len(skirtlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(skirtlinkList))

      msg = str(skirttempList[i]) + "℃\n" + str(skirttagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=skirtlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
        
  elif data == '코트':
      if (len(coatlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")  
        
      i = random.randint(0,len(coatlinkList))

      msg = str(coattempList[i]) + "℃\n" + str(coattagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=coatlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
      
  elif data == '긴바지':
      if (len(lbotlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(lbotlinkList))

      msg = str(lbottempList[i]) + "℃\n" + str(lbottagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=lbotlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
      
  elif data == '숏팬츠':
      if (len(sbotlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(sbotlinkList))

      msg = str(sbottempList[i]) + "℃\n" + str(sbottagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=sbotlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
      
  elif data == '원피스':
      if (len(oplinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(oplinkList))

      msg = str(optempList[i]) + "℃\n" + str(optagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=oplinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
      
  elif data == '기타 재킷':
      if (len(jacketlinkList) == 0):
        context.bot.send_message(
            chat_id=update.effective_chat.id
            , text="없음")
        
      i = random.randint(0,len(jacketlinkList))

      msg = str(jackettempList[i]) + "℃\n" + str(jackettagList[i])
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=jacketlinkList[i])
    
      context.bot.send_message(
            chat_id=update.effective_chat.id
            , text=msg)
    
  elif data == 'reset':
    #태그 조건 초기화
    context.bot.send_message(
            chat_id=update.effective_chat.id
            , text='태그 초기화 완료')

def weather(update, context):
  context.bot.send_message(chat_id=update.effective_chat.id, text="{} 날씨".format(context.args[0]))
  weather = ""

  #버튼
  task_buttons = [[
        InlineKeyboardButton( '사진 보기', callback_data='snap' )
        , InlineKeyboardButton( '태그', callback_data='tag' )
    ], [
        InlineKeyboardButton( '태그 초기화', callback_data='reset' )
    ]]

  mark_up = InlineKeyboardMarkup(task_buttons)

  url = "https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query={}+날씨".format(context.args[0])
  r = requests.get(url)
  bs = BeautifulSoup(r.text,"lxml")
  weather_info = bs.select("div._today")
    
  temperature = bs.select("div.temperature_text")
  cast_text = bs.select("p.summary")
  indicator = bs.select("dl.summary_list")

  temperature = temperature[0].text.strip()
  txt = cast_text[0].text.strip()
  indicator = indicator[0].text.strip()

  weather = "{}C\r\n{}\r\n{}".format(temperature, txt, indicator)
  context.bot.send_message(chat_id=update.message.chat_id, text=weather,reply_markup = mark_up)
  

start_handler = CommandHandler('start', start)
dispatcher.add_handler(start_handler)

help_handler = CommandHandler('help', help)
dispatcher.add_handler(help_handler)

weather_handler = CommandHandler('weather', weather)
dispatcher.add_handler(weather_handler)

button_callback_handler = CallbackQueryHandler(cb_button)
dispatcher.add_handler(button_callback_handler)

task_buttons_handler = CommandHandler( 'task', cmd_task_buttons )
dispatcher.add_handler( task_buttons_handler )

tag_handler = CommandHandler('tag', tag)
dispatcher.add_handler(tag_handler)

taghelp_handler = CommandHandler('taghelp', taghelp)
dispatcher.add_handler(taghelp_handler)



# polling
updater.start_polling() 
#updater.idle()
